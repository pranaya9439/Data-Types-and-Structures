# %%
#  Create a string with your name and print it

name = "Pranay"
print("1. My name is:", name)

#  Find the length of the string "Hello World"

text = "Hello World"
print("2. Length of 'Hello World':", len(text))

#  Slice the first 3 characters from the string "Python Programming"

s = "Python Programming"
print("3. First 3 characters:", s[:3])

#  Convert the string "hello" to uppercase

word = "hello"
print("4. Uppercase:", word.upper())

#  Replace "apple" with "orange" in the string "I like apple"

sentence = "I like apple"
new_sentence = sentence.replace("apple", "orange")
print("5. Replaced string:", new_sentence)

#  Create a list with numbers 1 to 5 and print it

numbers = [1, 2, 3, 4, 5]
print("6. List from 1 to 5:", numbers)

#  Append the number 10 to the list [1, 2, 3, 4]

lst = [1, 2, 3, 4]
lst.append(10)
print("7. List after appending 10:", lst)

#  Remove the number 3 from the list [1, 2, 3, 4, 5]

lst2 = [1, 2, 3, 4, 5]
lst2.remove(3)
print("8. List after removing 3:", lst2)

#  Access the second element in the list ['a', 'b', 'c', 'd']

letters = ['a', 'b', 'c', 'd']
print("9. Second element:", letters[1])

# Reverse the list [10, 20, 30, 40, 50]

lst3 = [10, 20, 30, 40, 50]
lst3.reverse()
print("10. Reversed list:", lst3)


#  Create a tuple with the elements 100, 200, 300 and print it

my_tuple = (100, 200, 300)
print("11. Tuple:", my_tuple)

#  Access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow')

colors = ('red', 'green', 'blue', 'yellow')
print("12. Second-to-last element:", colors[-2])

# Find the minimum number in the tuple (10, 20, 5, 15)

numbers = (10, 20, 5, 15)
print("13. Minimum number:", min(numbers))

#  Find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit')

animals = ('dog', 'cat', 'rabbit')
print("14. Index of 'cat':", animals.index('cat'))

#  Create a tuple containing three different fruits and check if "kiwi" is in it

fruits = ('apple', 'banana', 'kiwi')
print("15. Is 'kiwi' in the tuple?", 'kiwi' in fruits)

#  Create a set with the elements 'a', 'b', 'c' and print it

my_set = {'a', 'b', 'c'}
print("16. Set:", my_set)

#  Clear all elements from the set {1, 2, 3, 4, 5}

numbers_set = {1, 2, 3, 4, 5}
numbers_set.clear()
print("17. Cleared set:", numbers_set)

#  Remove the element 4 from the set {1, 2, 3, 4}

nums = {1, 2, 3, 4}
nums.remove(4)
print("18. Set after removing 4:", nums)

# Find the union of two sets {1, 2, 3} and {3, 4, 5}

set1 = {1, 2, 3}
set2 = {3, 4, 5}
union_set = set1.union(set2)
print("19. Union:", union_set)

#  Find the intersection of two sets {1, 2, 3} and {2, 3, 4}

a = {1, 2, 3}
b = {2, 3, 4}
intersection = a.intersection(b)
print("20. Intersection:", intersection)

#  Create a dictionary with the keys "name", "age", and "city", and print it

person = {"name": "Alice", "age": 30, "city": "New York"}
print("21. Dictionary:", person)

#  Add a new key-value pair "country": "USA" to the dictionary {'name': 'John', 'age': 25}

person2 = {'name': 'John', 'age': 25}
person2['country'] = 'USA'
print("22. Updated dictionary:", person2)

#  Access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30}

data = {'name': 'Alice', 'age': 30}
print("23. Value of 'name':", data['name'])

#  Remove the key "age" from the dictionary {'name': 'Bob', 'age': 22, 'city': 'New York'}

info = {'name': 'Bob', 'age': 22, 'city': 'New York'}
del info['age']
print("24. Dictionary after removing 'age':", info)

#  Check if the key "city" exists in the dictionary {'name': 'Alice', 'city': 'Paris'}

profile = {'name': 'Alice', 'city': 'Paris'}
print("25. Is 'city' a key?", 'city' in profile)

#  Create a list, a tuple, and a dictionary, and print them all

my_list = [1, 2, 3]
my_tuple2 = (4, 5, 6)
my_dict = {'a': 1, 'b': 2}
print("26. List:", my_list)
print("26. Tuple:", my_tuple2)
print("26. Dictionary:", my_dict)

#  Create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the result

import random
random_list = random.sample(range(1, 101), 5)
random_list.sort()
print("27. Sorted random numbers:", random_list)

#  Create a list with strings and print the element at the third index

words = ["apple", "banana", "cherry", "date", "fig"]
print("28. Element at third index:", words[3])

#  Combine two dictionaries into one and print the result

dict1 = {'a': 1, 'b': 2}
dict2 = {'c': 3, 'd': 4}
combined = {**dict1, **dict2}
print("29. Combined dictionary:", combined)

#  Convert a list of strings into a set

string_list = ["apple", "banana", "apple", "cherry"]
string_set = set(string_list)
print("30. Set from list:", string_set)
# Out:
# 1. My name is: Pranay
# 2. Length of 'Hello World': 11
# 3. First 3 characters: Pyt
# 4. Uppercase: HELLO
# 5. Replaced string: I like orange
# 6. List from 1 to 5: [1, 2, 3, 4, 5]
# 7. List after appending 10: [1, 2, 3, 4, 10]
# 8. List after removing 3: [1, 2, 4, 5]
# 9. Second element: b
# 10. Reversed list: [50, 40, 30, 20, 10]
# 11. Tuple: (100, 200, 300)
# 12. Second-to-last element: blue
# 13. Minimum number: 5
# 14. Index of 'cat': 1
# 15. Is 'kiwi' in the tuple? True
# 16. Set: {'b', 'a', 'c'}
# 17. Cleared set: set()
# 18. Set after removing 4: {1, 2, 3}
# 19. Union: {1, 2, 3, 4, 5}
# 20. Intersection: {2, 3}
# 21. Dictionary: {'name': 'Alice', 'age': 30, 'city': 'New York'}
# 22. Updated dictionary: {'name': 'John', 'age': 25, 'country': 'USA'}
# 23. Value of 'name': Alice
# 24. Dictionary after removing 'age': {'name': 'Bob', 'city': 'New York'}
# 25. Is 'city' a key? True
# 26. List: [1, 2, 3]
# 26. Tuple: (4, 5, 6)
# 26. Dictionary: {'a': 1, 'b': 2}
# 27. Sorted random numbers: [3, 16, 76, 82, 95]
# 28. Element at third index: date
# 29. Combined dictionary: {'a': 1, 'b': 2, 'c': 3, 'd': 4}
# 30. Set from list: {'banana', 'apple', 'cherry'}
